# %% [markdown]
# # Piccard - v2013.12: Pulsar Timing Array data analysis package#

# %%
import numpy as np, matplotlib.pyplot as plt
import piccard as pic
import os, glob

# %%
# Version of the library
pic.__version__
# Out:
# 2014.01

# %% [markdown]
# ## HDF5 files ##
# Piccard does not work with raw par/tim files as Tempo/Tempo2 do. It requires the par/tim files to be processed beforehand. The pulsar data is stored in HDF5 files, which Piccard interacts with through the h5py package. HDF5 files can be made from par/tim files with Piccard thanks to the libstempo interface to Tempo2
#
# ### Creating the HDF5 files ###
# Assume we have a pulsar (J0030 from the first IPTA Mock Data Challenge, open1, here), and read it in an HDF5 file

# %%
# Creating hdf5 files goes through the DataFile class
! rm J0030.h5   # Delete it if it exists (otherwise causes an error)
t2df = pic.DataFile('J0030.h5')
t2df.addTempoPulsar('mdc1-open1/J0030+0451.par', 'mdc1-open1/J0030+0451.tim')

# This automatically writes and closes the file.

# %% [markdown]
# ### Creating multi-pulsar sets ###
# A single HDF5 file can host multiple pulsars. Say we want to place all pulsars of mdc1-open1 in one HDF5 file, we would do:

# %%
! rm mdc1-open1.h5   # Delete it if it exists (otherwise causes an error)
t2df = pic.DataFile('mdc1-open1.h5')
for infile in glob.glob(os.path.join('mdc1-open1/', '*.par') ):
    filename = os.path.splitext(infile)
    parfile = filename[0]+'.par'
    timfile = filename[0]+'.tim'
    
    t2df.addTempoPulsar(parfile, timfile)

# %% [markdown]
# ## Creating a model for a dataset ##
# The goal is to create a likelihood function. In Piccard, likelihood functions are represented by objects of the type ptaLikelihood. A likelihood function needs both observations, and a description of the model. The data is read from HDF5 files. A model can be stored in JSON files, but we can also create models on the fly. Here we'll show how to do such things.

# %%
# With a datafile, we can construct a 'likelihood' object, which is the central class of the package
likob = pic.ptaLikelihood('J0030.h5')

# %%
# Create a very simple Python dictionary that represents a model
modeldict = likob.makeModelDict(varyEfac=True, nfreqs=10, incRedNoise=True, noiseModel='powerlaw')
print modeldict    # The dictionary is human-readable
# Out:
# {'likfunc': 'mark1', 'compression': 'frequencies', 'pulsarnames': [u'J0030+0451'], 'author': 'piccard-makeModel', 'orderFrequencyLines': False, 'signals': [{'flagvalue': u'J0030+0451', 'pwidth': [0.1], 'flagname': 'pulsarname', 'pstart': [1.0], 'pmin': [0.001], 'stype': 'efac', 'corr': 'single', 'pulsarind': 0, 'pmax': [50.0], 'bvary': [True]}, {'flagvalue': u'J0030+0451', 'pwidth': [0.1, 0.1, 5e-11], 'flagname': 'pulsarname', 'pstart': [-14.0, 2.01, 1e-10], 'pmin': [-20.0, 0.02, 1e-11], 'stype': 'powerlaw', 'corr': 'single', 'pulsarind': 0, 'pmax': [-10.0, 6.98, 3e-09], 'bvary': [True, True, False]}], 'file version': 2013.12, 'numpulsars': 1, 'evalCompressionComplement': True, 'numNoiseFreqs': [10], 'numDMFreqs': [0]}

# %%
# We now have created a model for J0030 with a varying Efac, and a red-noise (10 frequencies) modelled similarly
# to what is done in the Tempo2 'spectralModal' plugin. We can apply the model as follows
likob.initModel(modeldict)

# The parameters of this model are viewable in the pardes dictionary.
# NOTE: likob.pardes is only descriptive. It is not used to change the model
for pd in likob.pardes:
    print pd

print "Number of dimensions: ", likob.dimensions
# Out:
# {'index': 0, 'name': 'pulsarname', 'sigtype': 'efac', 'sigindex': 0, 'correlation': 'single', 'pulsar': 0, 'id': u'efacJ0030+0451'}
# {'index': 1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-Amplitude'}
# {'index': 2, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-spectral-index'}
# {'index': -1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'low-frequency-cutoff'}
# Number of dimensions:  3

# %% [markdown]
# #### Remember the pardes parameter descriptions. ####
# Especially the 'index' field could become useful. It is the unique index of the parameter when calling the likelihood function. You can see here that the 'low-frequency-cutoff' does not have a non-negative index, since it is a fixed parameter. In the model dictionary you can see that bvary for this signal had [True, True, False], with the last parameter the 'low-frequency-cutoff'.

# %%
# The model can be saved to a JSON file with
likob.writeModelToFile('J0030.json')

# A model can be read-in with
likob.initModelFromFile('J0030.json')

# Given a likelihood object, the model dictionary can be obtained with
modeldict = likob.getModelDict()

# Finally, a likelihood object can also be created with a model included
likob = pic.ptaLikelihood('J0030.h5', 'J0030.json')

# %%
# The parameter space is 3 dimensional: (efac, red-noise-amplitude, red-noise-spectral-index)
print "Minimum bound:", likob.pmin
print "Maximum bound:", likob.pmax
print "Starting position:", likob.pstart
# Out:
# Minimum bound: [  1.00000000e-03  -2.00000000e+01   2.00000000e-02]
# Maximum bound: [ 50.   -10.     6.98]
# Starting position: [  1.   -14.     2.01]

# %%
# With a fully initialised likelihood object, we have access to the likelihood, prior, and posterior
print likob.logprior(likob.pstart), likob.loglikelihood(likob.pstart), likob.logposterior(likob.pstart)
print likob.logposterior([1.0, np.log10(5e-14), 4.33])   # These are the injected values for mdc1-open1
# Out:
# -8.15476757257 1018.40322829 1010.24846072
# 1762.1054453

# %% [markdown]
# ## Combining data models from separate HDF5/JSON files ##
# A very likely scenario to occur is that of a staged analysis: first the pulsars will be analysed individually in some noise analysis. After the noise analysis has been properly done, the results will all be formatted in (*.par, *.tim, *.h5, *.json) files. One of those for each pulsar. However, at that point, the data and models should all be combined, and a single h5/JSON file will be required. Making the combined model would require quite some work, and creating a new full dataset might be computationally expensive for large datasets (creating the likelihood Auxiliaries can take quite some time). The combination utilities in Piccard allow one to do such combining tasks

# %%
# We will create three separate sets for the first mock data challenge: J0xxx.par, J1xxx.par, J2xxx.par.
! rm mdc1-J0xxx.h5   # Delete it if it exists (otherwise causes an error)
! rm mdc1-J1xxx.h5
! rm mdc1-J2xxx.h5

t2df = pic.DataFile('mdc1-J0xxx.h5')
for infile in glob.glob(os.path.join('mdc1-open1/', 'J0*.par') ):
    filename = os.path.splitext(infile)
    parfile = filename[0]+'.par'
    timfile = filename[0]+'.tim'
    
    t2df.addTempoPulsar(parfile, timfile)

t2df = pic.DataFile('mdc1-J1xxx.h5')
for infile in glob.glob(os.path.join('mdc1-open1/', 'J1*.par') ):
    filename = os.path.splitext(infile)
    parfile = filename[0]+'.par'
    timfile = filename[0]+'.tim'
    
    t2df.addTempoPulsar(parfile, timfile)

t2df = pic.DataFile('mdc1-J2xxx.h5')
for infile in glob.glob(os.path.join('mdc1-open1/', 'J2*.par') ):
    filename = os.path.splitext(infile)
    parfile = filename[0]+'.par'
    timfile = filename[0]+'.tim'
    
    t2df.addTempoPulsar(parfile, timfile)

# %%
likoblist = [] ; modellist = []

# Read in the HDF5 files
likoblist.append(pic.ptaLikelihood('mdc1-J0xxx.h5'))
likoblist.append(pic.ptaLikelihood('mdc1-J1xxx.h5'))
likoblist.append(pic.ptaLikelihood('mdc1-J2xxx.h5'))


# The models are very similar
modellist.append(likoblist[0].makeModelDict(varyEfac=True, nfreqs=5, incRedNoise=True, noiseModel='powerlaw'))
modellist.append(likoblist[1].makeModelDict(varyEfac=True, nfreqs=10, incRedNoise=True, noiseModel='spectrum'))
modellist.append(likoblist[2].makeModelDict(varyEfac=True, nfreqs=20, incRedNoise=True, noiseModel='spectralModel'))

# If we would like, we could apply the models, and write to disk
# likoblist[0].initModel(modellist[0])
# likoblist[0].writeModelToFile('mdc1-J0xxx.json')

# %%
# Ok, fine, we have the separate models. Now we can combine them like this
likob = pic.ptaLikelihood('mdc1-open1.h5') # The full set
fullmodel = likob.combineModelDicts(*modellist)

# %%
likob.initModel(fullmodel)
likob.logposterior(likob.pstart)
# Out:
# 49379.984070392129

# %%
# This was only the combination of the models. Now we will show how to combine the HDF5 files. This is done
# through the DataFile class
! rm mdc1-open1.h5
t2df = pic.DataFile('mdc1-open1.h5')
t2df.addH5Pulsar('mdc1-J0xxx.h5', pulsars='all', mode='add')
t2df.addH5Pulsar('mdc1-J1xxx.h5', pulsars='all', mode='add')
t2df.addH5Pulsar('mdc1-J2xxx.h5', pulsars='all', mode='add')

# %%
# Now we have a fully ready mdc1 file again
likob = pic.ptaLikelihood('mdc1-open1.h5') # The full set
likob.initModel(fullmodel)
likob.logposterior(likob.pstart)
# Out:
# 49379.984070392129

# %% [markdown]
# # Simulating data #
# Piccard allows the simulation of data for single pulsars and multiple pulsars through the function 'simulateFullSet'. What is required is an already existing set of par/tim files. Piccard will then take the sampling, and create new realisation of data based on some model that needs to be provided.

# %%
# We need a list of the par-files, tim-files, and the sim-files we will use.
# The par/tim files are input. the sim-files are output
parlist = [] ; timlist = [] ; simlist = []

for infile in glob.glob(os.path.join('./mdc1-open1/', '*.par') ):
    filename = os.path.splitext(infile)
    parlist.append(filename[0]+'.par')
    timlist.append(filename[0]+'.tim')
    simlist.append(filename[0]+'.sim')

# Print the first three par-files
print parlist[:3]
# Out:
# ['./mdc1-open1/J0030+0451.par', './mdc1-open1/J0218+4232.par', './mdc1-open1/J0437-4715.par']

# %%
# Above we called the function 'makeModelDict' using keywords given to the function.
# Here we'll use a dictionary first, since we'll need these quantities a few times
model = {'nfreqs':10, 'varyEfac':True, 'incEquad':False, 'incRedNoise':True, \
                    'noiseModel':'powerlaw', 'incGWB':True, 'gwbModel':'powerlaw'}

# Per pulsar: efac, red-noise amp, red-noise spectral index
# At the end: GWB amplitude, GWB spectral index
# The list of parameters therefore becomes:
p = len(parlist)   # The number of pulsars we read in
parameters = [1.0, -18.0, 4.33]*p + [np.log10(5e-15), 4.33]

# %%
# Simulate the data:
! rm mockdata.h5
pic.simulateFullSet(parlist, timlist, simlist, parameters, 'mockdata.h5', **model)
# Out:
# Writing mock TOAs of  ./mdc1-open1/J0030+0451.par / J0030+0451  to  ./mdc1-open1/J0030+0451.sim
# Writing mock TOAs of  ./mdc1-open1/J0218+4232.par / J0218+4232  to  ./mdc1-open1/J0218+4232.sim
# Writing mock TOAs of
#  ./mdc1-open1/J0437-4715.par / J0437-4715  to  ./mdc1-open1/J0437-4715.sim
# Writing mock TOAs of  ./mdc1-open1/J0613-0200.par / J0613-0200  to  ./mdc1-open1/J0613-0200.sim
# Writing mock TOAs of
#  ./mdc1-open1/J0621+1002.par / J0621+1002  to  ./mdc1-open1/J0621+1002.sim
# Writing mock TOAs of  ./mdc1-open1/J0711-6830.par / J0711-6830  to  ./mdc1-open1/J0711-6830.sim
# Writing mock TOAs of
#  ./mdc1-open1/J0751+1807.par / J0751+1807  to  ./mdc1-open1/J0751+1807.sim
# Writing mock TOAs of  ./mdc1-open1/J0900-3144.par / J0900-3144  to  ./mdc1-open1/J0900-3144.sim
# Writing mock TOAs of
#  ./mdc1-open1/J1012+5307.par / J1012+5307  to  ./mdc1-open1/J1012+5307.sim
# Writing mock TOAs of  ./mdc1-open1/J1022+1001.par / J1022+1001  to  ./mdc1-open1/J1022+1001.sim
# ...

# %%
# Plot all the residuals in the file mockset.h5
likob = pic.ptaLikelihood('mockdata.h5')

plt.figure(figsize=(16,11))
for ii in range(len(likob.ptapsrs)):
    plt.subplot(9, 4,ii+1)
    plt.errorbar(likob.ptapsrs[ii].toas, likob.ptapsrs[ii].residuals, \
                 yerr=likob.ptapsrs[ii].toaerrs, fmt='.', c='b')
    
    plt.annotate(likob.ptapsrs[ii].name, \
                 xy=(0.02, 0.20), xycoords='axes fraction', \
                 bbox=dict(boxstyle="round", fc="1.0"))
    #plt.axis([53000, 55000, -5e-7, 5e-7])
    plt.grid(True)

# %% [markdown]
# # Analysing data #
# ## The likelihood functions ##
# Piccard offers a multitude of different likelihood functions. They are all different approximations of the same likelihood function, representing random Gaussian process. However, some are more efficient than others, and some cannot deal with specific types of signals. They are labelled mark1-mark10.
#
# * **'mark1'** The default. It calculates the likelihood without doing any woodbury expansion. Can include red signals and DM variations. Can be combined with compression
# * **'mark2'** Only white noise (efac + equad). Fastest
# * **'mark3'** Woodbury expansion for red signals (noise or other) only. No DM variations. Can be combined with compression
# * **'mark3fa'** Same as mark3, but uses a first-order approximation for pulsar-correlated signals. Faster than mark3 for PTAs.
# * **'mark4'** Woodbury expansion for averaged TOAs (as we have for NANOGrav). Can be combined with compression. Can include red noise and DM variations. Must include a jitter noise component. Can be combined with compression (but probably not useful).
# * **'mark4ln'** Same as mark4, but can include floating frequency lines. Can be combined with compression
# * **'mark6'** Same as mark3, but can include DM variations. Can be combined with compression
# * **'mark6fa'** Same as mark6, but uses a first-order approximation for pulsar-correlated signals.
# * **'mark7'** (Unsupported) Same as mark3, but can be used in RJMCMC methods for mode-selection.
# * **'mark8'** (Unsupported) Same as mark6, but can be used in RJMCMC methods for mode-selection.
# * **'mark9'** (Unsupported) Same as mark3, but can include floating frequency lines. Can be combined with compression
# * **'mark10'** (Unsupported) Same as mark6, but can include floating frequency lines. Can be combined with compression
#
# Besides these choices of likelihood functions, one can set the 'compression' parameter. This uses an updated version of the ABC-compression method of [van Haasteren (2013)](http://arxiv.org/abs/1210.0584). The compression can be done either on the modelled frequencies (of both red signals and DM variations), or on the averaged TOAs. In contrast to the original ABC-compression method, the implementation of Piccard will also evaluate the complement of the likelihood function so no data is thrown away. The results are virtually identical to those of the Woodbury expansion methods, except that it is slightly faster. This method is therefore preferred, and the current default
#
# Note: be very careful when using likelihoods with and without compression on the same dataset (h5file). Since the compression matrix can be anything we'd like, it is rather difficult to check whether the compression matrix we have on file is actually what we want. An uncompressed dataset would just make the compression matrix equal to G. Therefore, when mixing it up, the safest bet is to always re-calculate all values, as here:
#
# likob.initModel(somemodel, fromFile=False)
#
# Or, of course, just always use compression. There is virtually no reason not to :)

# %%
# Create a model with efac, red noise, and GWB, for dataset mdc1-open1
likob = pic.ptaLikelihood('mdc1-open1.h5')
mark1model = likob.makeModelDict(varyEfac=True, nfreqs=20, \
                                incRedNoise=True, noiseModel='powerlaw', \
                                incGWB=True, gwbModel='powerlaw', \
                                compression='frequencies', evalCompressionComplement=True, \
                                likfunc='mark1')
mark3model = likob.makeModelDict(varyEfac=True, nfreqs=20, \
                                incRedNoise=True, noiseModel='powerlaw', \
                                incGWB=True, gwbModel='powerlaw', \
                                compression=None, evalCompressionComplement=False, \
                                likfunc='mark3')
likob.initModel(mark1model)
likob.writeModelToFile('mdc1-open1.json')
pars = likob.pstart.copy()
# Out:
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# ...

# %%
# Both likelihoods give approximately the same answer
likob.initModel(mark1model, fromFile=False, verbose=True)
print "Mark1:", likob.logposterior(pars)
likob.initModel(mark3model, fromFile=False, verbose=True)
print "Mark3:", likob.logposterior(pars)

# Note however, that for mark1, the complement of the likelihood function is evaluated
# likob.initModel(mark1model)
# print "Mark1:", likob.loglikelihood(pars), "=", likob.mark1loglikelihood(pars), "+", likob.comploglikelihood(pars)
# In the original ABC-compression paper, only 'mark1loglikelihood(pars) was evaluated.
# The implementation in Piccard is such that the user should not worry about it.
# Out:
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0030+0451
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0218+4232
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0437-4715
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0613-0200
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0621+1002
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0711-6830
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0751+1807
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J0900-3144
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J1012+5307
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J1022+1001
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J1024-0719
# Requested to re-create the Auxiliaries
# Creating Auxiliaries for J1045-4509
# Requested to re-create the Auxiliaries
# ...

# %% [markdown]
# ## Finding more optimal compression levels ##
# The standard compression will compress down to the number of frequencies that we have included in our model. But that number is given in the JSON file, which ultimately is made with 'makeModelDict'. How can we decide, based on the data, how many frequencies we need to include in our model? This issue has been discussed in the literature. See for instance:
#
# * [van Haasteren (2013)](http://arxiv.org/abs/1210.0584)
# * [Lentati et al. (2013)](http://arxiv.org/abs/1210.3578)
#
# In Piccard we have a simplified approach (for now). We evaluate the 99% fidelity level to recover a signal of a certain spectral shape and amplitude, and we use that. The spectral shape is a power-law with a certain slope, and the noise is assumed (conservatively) to consist only of the radiometer noise without applied efac. This is how it is done. (TODO: make this into a function...)

# %%
# We assume we have written mdc1-open1.json to file above
likob = pic.ptaLikelihood('mdc1-open1.h5', 'mdc1-open1.json')
mark1dict = likob.getModelDict()

# Determine the number of frequencies using 'numfreqsFromSpectrum'
numfreqs = np.zeros(len(likob.ptapsrs), dtype=np.int)
for ii, psr in enumerate(likob.ptapsrs):
    numfreqs[ii] = psr.numfreqsFromSpectrum(noiseAmp=5e-14, noiseSi=4.33, threshold=0.99)

# Set the number of frequencies in the model dictionary, and re-initialise the likelihood object
mark1dict['numNoiseFreqs'] = numfreqs
likob.initModel(mark1dict)
likob.writeModelToFile('mdc1-open1.json')
# Out:
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# WARNING: model frequencies already present in mdc1-open1.h5 differ from the current
#          model. Overwriting...
# ...

# %%
# The number of frequencies per pulsar now is (only half of the mode-frequencies, since we have two modes per frequency):
print [int(len(likob.ptapsrs[ii].Ffreqs)/2) for ii in range(len(likob.ptapsrs))]
# Out:
# [12, 11, 11, 12, 12, 12, 13, 13, 12, 13, 12, 12, 12, 10, 12, 11, 10, 12, 13, 13, 11, 13, 12, 12, 12, 12, 11, 13, 12, 12, 11, 12, 12, 10, 9, 12]

# %% [markdown]
# ## Performing a simple parameter search ##
# A simple parameter search can be done

# %% [markdown]
# ## Non-linear pulsar timing analysis ##
# Doing non-linear timing data analysis is also possible

# %%
import numpy as np, matplotlib.pyplot as plt
import piccard as pic
import os, glob
likob = pic.ptaLikelihood('J0030.h5')
modeldict = likob.makeModelDict(varyEfac=True, nfreqs=10, incRedNoise=True, noiseModel='powerlaw', \
                                incTimingModel=True, nonLinear=True, \
                                compression='qsd', likfunc='mark3')
likob.initModel(modeldict, fromFile=False)

# %%
likob.logposterior(likob.pstart)
# Out:
# 996.63362052060143992

# %%
pic.RunMultiNest(likob, './tempchain/')

# %%
(lp, ll, chain, labels) = pic.ReadMCMCFile('./tempchain/')

# %%
pic.triplot(chain, labels)

# %%
# Note: from here onwards, the demo is outdated...

# %%
# The default start parameters, minimum value, maximum value, and stepsize
# Parameter indices belong to the 'index' key of the likob.pardes dictionary.
# A '-1' in the pardes dictionary means that the parameter is kept fixed in a
# subsequent analysis.
print likob.pstart, likob.pmin, likob.pmax, likob.pwidth
# Out:
# [  1.   -14.     2.01] [  1.00000000e-03  -2.00000000e+01   2.00000000e-02] [  5.   -10.     6.98] [ 0.1  0.1  0.1]

# %%
# Calculate the value of the posterior, likelihood, or prior:
print likob.logprior(likob.pstart), likob.loglikelihood(likob.pstart), likob.logposterior(likob.pstart)
# Out:
# -5.85200245977
# 1020.1307407 1014.27873824

# %%
# Run a t-walk algorithm on the posterior for 20000 steps (analyse=True prints the figure)
pic.Runtwalk(likob, 20000, 'J0030-twalk-burnin.txt', thin=5, analyse=True)
# Out:
# pytwalk: Running the twalk with 20000 iterations. Mon, 16 Dec 2013, 16:24.
#        Finish in approx. 17 seconds.
# pytwalk: finished, Mon, 16 Dec 2013, 16:24:53.
# Acceptance rates for the Walk, Traverse, Blow and Hop kernels:[ 0.44760449  0.15563887  0.11643836  0.02285714]
# Global acceptance rate: 0.29740
# AutoMaxlag: maxlag= 123.
# Integrated Autocorrelation Time:    10.4, IAT/n:     3.5

# %%
# Removing the burn-in of the MCMC chains is easy on the command line
# !sed '1,300d' J0030-twalk-burnin.txt > J0030-twalk.txt

# %%
# We can run a more optimal Metropolis algorithm by using the t-walk as a tuning chain
pic.RunMetropolis(likob, 20000, 'J0030-metro.txt', initfile='J0030-twalk.txt', resize=1.0)
# Out:
# Obtaining initial positions from 'J0030-twalk.txt'
# Running Metropolis-Hastings sampler
# Sample: 0 =  0.0%   acc. fr. = 0.455446   pos = -1.336963e+01 4.730071e+00  lnprob = 1.869844e+03
# Sample: 100 =  0.5%   acc. fr. = 0.427861   pos = -1.314291e+01 5.782383e+00  lnprob = 1.869469e+03
# Sample: 200 =  1.0%   acc. fr. = 0.425249   pos = -1.315614e+01 4.782837e+00  lnprob = 1.869856e+03
# Sample: 300 =  1.5%   acc. fr. = 0.428928   pos = -1.312713e+01 4.715323e+00  lnprob = 1.871079e+03
# Sample: 400 =  2.0%   acc. fr. = 0.411178   pos = -1.330716e+01 4.888174e+00  lnprob = 1.871955e+03
# Sample: 500 =  2.5%   acc. fr. = 0.414309   pos = -1.322717e+01 4.941007e+00  lnprob = 1.871493e+03
# Sample: 600 =  3.0%   acc. fr. = 0.430813   pos = -1.326825e+01 3.895368e+00  lnprob = 1.870740e+03
# Sample: 700 =  3.5%   acc. fr. = 0.419476   pos = -1.332891e+01 4.395801e+00  lnprob = 1.871639e+03
# ...

# %%
# The parameters in the chain are stored in 'J0030-metro.txt.parameters.txt'.
# All sampler routines use this convention
# !cat J0030-metro.txt.parameters.txt
# Out:
# 0 	0 	efac 	single 	pulsarname 	efacJ0030+0451
# 1 	0 	powerlaw 	single 	powerlaw 	RN-Amplitude
# 2 	0 	powerlaw 	single 	powerlaw 	RN-spectral-index
# -1 	0 	powerlaw 	single 	powerlaw 	low-frequency-cutoff

# %%
# Plot the results of the MCMC (which uses the .parameters.txt file)
pic.triplot('J0030-metro.txt')
# Out:
# parametersfilename =  J0030-metro.txt.parameters.txt
# figurefilename =  J0030-metro.txt.fig.eps
# chainfilename =  J0030-metro.txt

# %%
# Note: evidence = 1857
# pic.RunMultiNest(likob, 'J0030-mn')

# %%
import numpy as np
import matplotlib.pyplot as plt
import piccard as pic

# %%
reload(pic)

# %%
# We are now going to do the same thing as above, but with different noise models. We make two extra likelihood objects:
likobsm = pic.ptaLikelihood('J0030.h5')    # Same model as in the Tempo2 'spectralModel' plugin
likobsp = pic.ptaLikelihood('J0030.h5')    # Frequencies individually parameterised

# %%
# Prepare the likelihood objects
likobsm.initModel(nfreqmodes=30, varyEfac=True, incRedNoise=True, noiseModel='spectralModel')
likobsp.initModel(nfreqmodes=30, varyEfac=True, incRedNoise=True, noiseModel='spectrum')

# %%
# Instead of using Metropolis, we'll now use MultiNest to sample. This time on the 'spectralModel' object
# TODO: MultiNest parameters in 'piccard.py' need to be tweaked a bit
# Note: evidence = 1858
pic.RunMultiNest(likobsm, 'J0030-sm')

# %%
# Plotting is done with the same triplot routine
pic.triplot('J0030-sm.txt')
# Out:
# parametersfilename =  J0030-sm.txt.parameters.txt
# figurefilename =  J0030-sm.txt.fig.eps
# chainfilename =  J0030-sm.txt

# %%
# For the spectrum, we'll do a t-walk/Metropolis combo again
pic.Runtwalk(likobsp, 50000, 'J0030-sp-twalk-burnin.txt', thin=5)
# !sed '1,300d' J0030-sp-twalk-burnin.txt > J0030-sp-twalk.txt
pic.RunMetropolis(likobsp, 50000, 'J0030-sp-metro.txt', initfile='J0030-sp-twalk.txt', resize=0.2)
# Out:
# pytwalk: Running the twalk with 50000 iterations. Thu, 12 Sep 2013, 14:52.
#        Finish in approx. 1 minutes and 46 seconds.
# pytwalk:      24576 iterations so far. Finish in approx. 32 seconds.
# pytwalk: finished, Thu, 12 Sep 2013, 14:53:23.
# Obtaining initial positions from 'J0030-sp-twalk.txt'
# Running Metropolis-Hastings sampler
# Sample: 0 =  0.0%   acc. fr. = 0.386139   pos = -1.640947e+01 -1.525659e+01  lnprob = 1.790729e+03
# Sample: 100 =  0.2%   acc. fr. = 0.412935   pos = -1.782604e+01 -1.651313e+01  lnprob = 1.800210e+03
# Sample: 200 =  0.4%   acc. fr. = 0.392027   pos = -1.608071e+01 -1.743164e+01  lnprob = 1.799771e+03
# Sample: 300 =  0.6%   acc. fr. = 0.418953   pos = -1.710821e+01 -1.794444e+01  lnprob = 1.799931e+03
# Sample: 400 =  0.8%   acc. fr. = 0.377246   pos = -1.778603e+01 -1.764337e+01  lnprob = 1.798346e+03
# Sample: 500 =  1.0%   acc. fr. = 0.354409   pos = -1.770444e+01 -1.772120e+01  lnprob = 1.796146e+03
# ...

# %%
# The spectrum of likobsp can be plotted
Tmax = likobsm.ptasignals[1].Tmax
pic.makespectrumplot('J0030-sp-metro.txt', parstart=1, numfreqs=30, freqs=likobsp.ptapsrs[0].Ffreqs, plotlog=True, Apl=np.log10(5e-14), gpl=4.33, Asm=-23.9, asm=4.7, Tmax=Tmax)

# %%
# Generating signals is possible, too
likob = pic.ptaLikelihood('J0030.h5')
likob.initModel(nfreqmodes=120, varyEfac=True, incRedNoise=True, noiseModel='powerlaw', likfunc='mark3')

# %%
parameters = likob.pstart
print parameters
# Out:
# [  1.   -14.     2.01]

# %%
parameters = np.array([1.0, -11, 6.73])

# %%
likob.gensig(parameters, timedomain=False)

# %%
# Analyzing Mingarelli-Vecchio anisotropic stochastic backgrounds with the Taylor-Gair method
reload(pic)
# Out:
# <module 'piccard' from 'piccard.py'>

# %%
# Create a likelihood object
likob = pic.ptaLikelihood('J0030.h5')

# %%
# Include power-law red noise, and a quadrupole aGWB (You can see how it can be modified)
likob.initModel(nfreqmodes=30, incRedNoise=True, noiseModel='powerlaw', incAniGWB=True, lAniGWB=2, anigwbModel='powerlaw', likfunc='mark3')

# %%
# As before, we now can run the chains
pic.Runtwalk(likob, 20000, 'J0030-ani-twalk-burnin.txt', thin=5, analyse=False)
# !sed '1,300d' J0030-ani-twalk-burnin.txt > J0030-ani-twalk.txt
pic.RunMetropolis(likob, 20000, 'J0030-ani-metro.txt', initfile='J0030-ani-twalk.txt', resize=1.0)
# Out:
# pytwalk: Running the twalk with 20000 iterations. Thu, 19 Sep 2013, 08:59.
#        Finish in approx. 6 seconds.
# pytwalk: finished, Thu, 19 Sep 2013, 08:59:35.
# Obtaining initial positions from 'J0030-ani-twalk.txt'
# Running Metropolis-Hastings sampler
# Sample: 0 =  0.0%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 100 =  0.5%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 200 =  1.0%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 300 =  1.5%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 400 =  2.0%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 500 =  2.5%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# Sample: 600 =  3.0%   acc. fr. = 0.000000   pos = -7.973995e+00 2.327632e+00  lnprob = -1.000000e+99
# ...

# %%
# Inspect the parameters
likob.dimensions
# Out:
# 12

# %%
for i in range(len(likob.pardes)): print likob.pardes[i]
# Out:
# {'index': -1, 'name': 'pulsarname', 'sigtype': 'efac', 'sigindex': 0, 'correlation': 'single', 'pulsar': 0, 'id': u'efacJ0030+0451'}
# {'index': 0, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-Amplitude'}
# {'index': 1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-spectral-index'}
# {'index': -1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'low-frequency-cutoff'}
# {'index': 2, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'anisotropicgwb', 'pulsar': -1, 'id': 'RN-Amplitude'}
# {'index': 3, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'anisotropicgwb', 'pulsar': -1, 'id': 'RN-spectral-index'}
# {'index': -1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'anisotropicgwb', 'pulsar': -1, 'id': 'low-frequency-cutoff'}
# ...

# %%
reload(pic)
# Out:
# <module 'piccard' from 'piccard.pyc'>

# %%
# Test for spectral lines
likob = pic.ptaLikelihood('J0030.h5')

# Construct a model with spectral lines
likob.initModel(nfreqmodes=10, varyEfac=False, incRedNoise=True, noiseModel='powerlaw', incSingleFreqNoise=True, likfunc='mark9')
# likob.initModel(nfreqmodes=30, varyEfac=False, incRedNoise=False, noiseModel='powerlaw', incSingleFreqNoise=True, likfunc='mark9')

# %%
likob.loglikelihood(likob.pstart)
# Out:
# 1120.3918857721901

# %%
for i in range(len(likob.pardes)):
    print likob.pardes[i]
# Out:
# {'index': -1, 'name': 'pulsarname', 'sigtype': 'efac', 'sigindex': 0, 'correlation': 'single', 'pulsar': 0, 'id': u'efacJ0030+0451'}
# {'index': 0, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-Amplitude'}
# {'index': 1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-spectral-index'}
# {'index': -1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': 'low-frequency-cutoff'}
# {'index': 2, 'name': 'frequencyline', 'sigtype': 'frequencyline', 'sigindex': 2, 'correlation': 'single', 'pulsar': 0, 'id': 'Line-Ampl'}
# {'index': 3, 'name': 'frequencyline', 'sigtype': 'frequencyline', 'sigindex': 2, 'correlation': 'single', 'pulsar': 0, 'id': 'Line-Freq'}

# %%
# Run a t-walk algorithm on the posterior for 20000 steps (analyse=True prints the figure)
pic.Runtwalk(likob, 20000, 'J0030-freqline-twalk-burnin.txt', thin=5, analyse=True)
# Out:
# pytwalk: Running the twalk with 20000 iterations. Wed, 09 Oct 2013, 15:10.
#        Finish in approx. 1 minutes and 15 seconds.
# pytwalk:      14336 iterations so far. Finish in approx. 11 seconds.
# pytwalk: finished, Wed, 09 Oct 2013, 15:10:47.
# Acceptance rates for the Walk, Traverse, Blow and Hop kernels:[ 0.32208158  0.06394389  0.02890173  0.00564972]
# Global acceptance rate: 0.19160
# AutoMaxlag: maxlag= 28.
# Integrated Autocorrelation Time:    10.0, IAT/n:     2.5

# %%
# !sed '1,300d' J0030-freqline-twalk-burnin.txt > J0030-freqline-twalk.txt
pic.RunMetropolis(likob, 20000, 'J0030-freqline-metro.txt', initfile='J0030-freqline-twalk.txt', resize=1.0)
# Out:
# Obtaining initial positions from 'J0030-freqline-twalk.txt'
# Running Metropolis-Hastings sampler
# Sample: 0 =  0.0%   acc. fr. = 0.118812   pos = -1.708254e+01 -6.824856e+00  lnprob = 1.872995e+03
# Sample: 100 =  0.5%   acc. fr. = 0.228856   pos = -1.735616e+01 -6.607658e+00  lnprob = 1.872620e+03
# Sample: 200 =  1.0%   acc. fr. = 0.282392   pos = -1.687229e+01 -6.969681e+00  lnprob = 1.871339e+03
# Sample: 300 =  1.5%   acc. fr. = 0.296758   pos = -1.523137e+01 -6.432773e+00  lnprob = 1.874088e+03
# Sample: 400 =  2.0%   acc. fr. = 0.295409   pos = -1.458142e+01 -7.885045e+00  lnprob = 1.875028e+03
# Sample: 500 =  2.5%   acc. fr. = 0.306156   pos = -1.769445e+01 -5.557796e+00  lnprob = 1.872728e+03
# Sample: 600 =  3.0%   acc. fr. = 0.289586   pos = -1.717089e+01 -6.557750e+00  lnprob = 1.873430e+03
# Sample: 700 =  3.5%   acc. fr. = 0.289638   pos = -1.682111e+01 -5.297331e+00  lnprob = 1.873857e+03
# ...

# %%
# Plot the results of the MCMC (which uses the .parameters.txt file)
pic.triplot('J0030-freqline-metro.txt')
# Out:
# parametersfilename =  J0030-freqline-metro.txt.parameters.txt
# figurefilename =  J0030-freqline-metro.txt.fig.eps
# chainfilename =  J0030-freqline-metro.txt

# %%
import numpy as np
import matplotlib.pyplot as plt
import piccard as pic

# %%
reload(pic)
# Out:
# <module 'piccard' from 'piccard.pyc'>

# %%
# Test for spectral lines
likob = pic.ptaLikelihood('J1640.h5')

# Construct a model with spectral lines
likob.initModel(nfreqmodes=4, varyEfac=True, incEquad=True, incRedNoise=True, noiseModel='powerlaw', incSingleFreqNoise=True, likfunc='mark9')
# likob.initModel(nfreqmodes=30, varyEfac=False, incRedNoise=False, noiseModel='powerlaw', incSingleFreqNoise=True, likfunc='mark9')

# %%
likob.pmin[3] = 0

# %%
for ii in range(len(likob.pardes)):
    print likob.pardes[ii]
# Out:
# {'index': 0, 'name': 'pulsarname', 'sigtype': 'efac', 'sigindex': 0, 'correlation': 'single', 'pulsar': 0, 'id': u'efac1640+2224'}
# {'index': 1, 'name': 'pulsarname', 'sigtype': 'equad', 'sigindex': 1, 'correlation': 'single', 'pulsar': 0, 'id': u'equad1640+2224'}
# {'index': 2, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-Amplitude'}
# {'index': 3, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'single', 'pulsar': 0, 'id': 'RN-spectral-index'}
# {'index': -1, 'name': 'powerlaw', 'sigtype': 'powerlaw', 'sigindex': 2, 'correlation': 'single', 'pulsar': 0, 'id': 'low-frequency-cutoff'}
# {'index': 4, 'name': 'frequencyline', 'sigtype': 'frequencyline', 'sigindex': 3, 'correlation': 'single', 'pulsar': 0, 'id': 'Line-Ampl'}
# {'index': 5, 'name': 'frequencyline', 'sigtype': 'frequencyline', 'sigindex': 3, 'correlation': 'single', 'pulsar': 0, 'id': 'Line-Freq'}

# %%
# Run a t-walk algorithm on the posterior for 20000 steps (analyse=True prints the figure)
pic.Runtwalk(likob, 20000, 'J1640-freqline-4modes-twalk-burnin.txt', thin=5, analyse=True)
# Out:
# pytwalk: Running the twalk with 20000 iterations. Wed, 09 Oct 2013, 16:12.
#        Finish by Wed, 09 Oct 2013, 16:22.
# pytwalk:       3072 iterations so far. Finish in approx. 2 minutes and 49 seconds.
# pytwalk:       9216 iterations so far. Finish in approx. 1 minutes and 50 seconds.
# pytwalk: finished, Wed, 09 Oct 2013, 16:15:24.
# Acceptance rates for the Walk, Traverse, Blow and Hop kernels:[ 0.23818256  0.05152652  0.06818182  0.        ]
# Global acceptance rate: 0.14290
# AutoMaxlag: maxlag= 211.
# Integrated Autocorrelation Time:    82.4, IAT/n:    13.7

# %%
# !sed '1,300d' J1640-freqline-4modes-twalk-burnin.txt > J1640-freqline-4modes-twalk.txt
pic.RunMetropolis(likob, 20000, 'J1640-freqline-4modes-metro.txt', initfile='J1640-freqline-4modes-twalk.txt', resize=1.0)
# Out:
# Obtaining initial positions from 'J1640-freqline-4modes-twalk.txt'
# Running Metropolis-Hastings sampler
# Sample: 0 =  0.0%   acc. fr. = 0.108911   pos = -1.758773e+01 -6.473910e+00  lnprob = 7.178137e+03
# Sample: 100 =  0.5%   acc. fr. = 0.139303   pos = -1.320833e+01 -4.673904e+00  lnprob = 7.176169e+03
# Sample: 200 =  1.0%   acc. fr. = 0.132890   pos = -1.323633e+01 -7.881796e+00  lnprob = 7.179750e+03
# Sample: 300 =  1.5%   acc. fr. = 0.147132   pos = -1.413464e+01 -5.422348e+00  lnprob = 7.174611e+03
# Sample: 400 =  2.0%   acc. fr. = 0.151697   pos = -1.415672e+01 -4.111533e+00  lnprob = 7.179091e+03
# Sample: 500 =  2.5%   acc. fr. = 0.159734   pos = -1.555101e+01 -5.746782e+00  lnprob = 7.176383e+03
# Sample: 600 =  3.0%   acc. fr. = 0.158345   pos = -1.297319e+01 -5.024913e+00  lnprob = 7.180049e+03
# Sample: 700 =  3.5%   acc. fr. = 0.141074   pos = -1.726969e+01 -7.654052e+00  lnprob = 7.176300e+03
# ...

# %%
# Plot the results of the MCMC (which uses the .parameters.txt file)
pic.triplot('J1640-freqline-4modes-metro.txt')
# Out:
# parametersfilename =  J1640-freqline-4modes-metro.txt.parameters.txt
# figurefilename =  J1640-freqline-4modes-metro.txt.fig.eps
# chainfilename =  J1640-freqline-4modes-metro.txt

# %%
# Run MultiNest
pic.RunMultiNest(likob, 'J1640-freqline-4modes-mn')

# %%
likob = pic.ptaLikelihood('nanograv/B1855+09_NANOGrav_dfg+12.h5')

# %%
likob.initModel(nfreqmodes=10, varyEfac=True, incEquad=True, incRedNoise=True, noiseModel='powerlaw', likfunc='mark3')

# %%
likob.logposterior(likob.pstart)
# Out:
# 7331.5451609063512

# %%
likob.dimensions
# Out:
# 4

# %%
pic.Runtwalk(likob, 50000, 'B1855-twalk.txt')
# Out:
# pytwalk: Running the twalk with 50000 iterations. Sun, 20 Oct 2013, 09:02.
#        Finish in approx. 43 seconds.
# pytwalk: finished, Sun, 20 Oct 2013, 09:03:16.

# %%
pic.triplot('B1855-twalk.txt')
# Out:
# parametersfilename =  B1855-twalk.txt.parameters.txt  (for MCMC)
# mnparametersfilename =  B1855-twalk.txt.mnparameters.txt  (for MultiNest)
# figurefilename =  B1855-twalk.txt.fig.eps
# chainfilename =  B1855-twalk.txt

# %%
pic.RunMultiNest(likob, 'B1855-mn')

# %%
pic.triplot('B1855-mnpost_equal_weights.dat')
# Out:
# parametersfilename =  B1855-mnpost_equal_weights.dat.parameters.txt  (for MCMC)
# mnparametersfilename =  B1855-mnpost_equal_weights.dat.mnparameters.txt  (for MultiNest)
# figurefilename =  B1855-mnpost_equal_weights.dat.fig.eps
# chainfilename =  B1855-mnpost_equal_weights.dat
